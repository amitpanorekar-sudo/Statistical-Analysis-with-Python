# %% [markdown]
# <h1> Q1. cheak the goodness of fit for the following data mapping number of hours a student studies  vs the expected number of hoursa student studies expected number of hours at 5% los  </h1>
#                                           # OBSERVED DATA  IN HOURS 8 6 10 7 8 11 9
#                                           # EXPECTED DATA  IN  HOURS 9 8 11 8 10 7 6

# %%
from scipy.stats import chisquare 
observed = [ 8,6,10,7,8,11,9,]
expected = [9,8,11,8,10,7,6]
chi_stat, p_value =chisquare(f_obs = observed ,f_exp = expected )

print ("chi-sqauare stats=",chi_stat)
print ("p-value = ",p_value)

alpha = 0.5
# Out:
# chi-sqauare stats= 5.0127344877344875
# p-value =  0.542180861413329

# %%
Q2.what is the probability of 2 heads in 6 coin tosses ? fit the binmoial distribution for the coin tosses and plot it

# %%
what is the probability
